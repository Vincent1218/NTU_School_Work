# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
traindata = pd.read_csv('train.csv')

# %%
print("Data dims : ", traindata.shape)
# Out:
# Data dims :  (1460, 81)

# %%
print(traindata.dtypes)
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
traindata
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
traindata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
traindata.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
html_data = pd.read_html('https://en.wikipedia.org/wiki/2016_Summer_Olympics_medal_table')

# %%
print("Data type : ", type(html_data))
print("HTML tables : ", len(html_data))
# Out:
# Data type :  <class 'list'>
# HTML tables :  6

# %%
html_data[0]
# Out:
#                                                    0
# 0                                Part of a series on
# 1  2016 Summer Olympics Bid process (bid details)...

# %%
html_data[1][0:61]
# Out:
#    Rank                  NOC  Gold  Silver  Bronze  Total
# 0     1  United States (USA)    46      37      38    121
# 1     2  Great Britain (GBR)    27      23      17     67
# 2     3          China (CHN)    26      18      26     70
# 3     4         Russia (RUS)    19      17      20     56
# 4     5        Germany (GER)    17      10      15     42
# ..  ...                  ...   ...     ...     ...    ...
# 56   54    Puerto Rico (PUR)     1       0       0      1
# 57   54      Singapore (SIN)     1       0       0      1
# 58   54     Tajikistan (TJK)     1       0       0      1
# 59   60       Malaysia (MAS)     0       4       1      5
# 60   61         Mexico (MEX)     0       3       2      5
#
# [61 rows x 6 columns]

# %%
html_data[2]
# Out:
#                                          Ruling date  \
# 0  List of official changes in medal standings (d...
# 1                                     18 August 2016
# 2                                     18 August 2016
# 3  List of official changes in medal standings (a...
# 4                                    8 December 2016
# 5                                    8 December 2016
# 6                                    8 December 2016
# 7                                    8 December 2016
# 8                                    30 January 2017
# 9                                    30 January 2017
#
#                                          Sport/Event  \
# 0  List of official changes in medal standings (d...
# 1                           WeightliftingMen's 69 kg
# 2                           WeightliftingMen's 69 kg
# 3  List of official changes in medal standings (a...
# 4                           WeightliftingMen's 85 kg
# 5                           WeightliftingMen's 85 kg
# ...

# %%
html_data[3]
# Out:
#                        vteOlympic Games medal tables  \
# 0  Olympic medal All-time Olympic Games medal tab...
# 1                               Summer Olympic Games
# 2                               Winter Olympic Games
# 3  Lists of Olympic medalists List of stripped Ol...
#
#                      vteOlympic Games medal tables.1
# 0  Olympic medal All-time Olympic Games medal tab...
# 1  1896 1900 1904 1908 1912 1920 1924 1928 1932 1...
# 2  1924 1928 1932 1936 1948 1952 1956 1960 1964 1...
# 3  Lists of Olympic medalists List of stripped Ol...

# %%
html_data[4]
# Out:
#                vteEvents at the 2016 Summer Olympics  \
# 0  Archery Athletics Badminton Basketball men wom...
#
#              vteEvents at the 2016 Summer Olympics.1
# 0  Archery Athletics Badminton Basketball men wom...

# %%
html_data[5]
# Out:
#       vteSummer Olympics medal table leaders by year  \
# 0  .mw-parser-output .div-col{margin-top:0.3em;co...
#
#     vteSummer Olympics medal table leaders by year.1
# 0  .mw-parser-output .div-col{margin-top:0.3em;co...

# %%
exdata = pd.DataFrame(html_data[1])

# %%
top20c=exdata[:20]

# %%
top20c
# Out:
#    Rank                  NOC  Gold  Silver  Bronze  Total
# 0     1  United States (USA)    46      37      38    121
# 1     2  Great Britain (GBR)    27      23      17     67
# 2     3          China (CHN)    26      18      26     70
# 3     4         Russia (RUS)    19      17      20     56
# 4     5        Germany (GER)    17      10      15     42
# 5     6          Japan (JPN)    12       8      21     41
# 6     7         France (FRA)    10      18      14     42
# 7     8    South Korea (KOR)     9       3       9     21
# 8     9          Italy (ITA)     8      12       8     28
# 9    10      Australia (AUS)     8      11      10     29
# 10   11    Netherlands (NED)     8       7       4     19
# 11   12        Hungary (HUN)     8       3       4     15
# 12   13        Brazil (BRA)*     7       6       6     19
# 13   14          Spain (ESP)     7       4       6     17
# 14   15          Kenya (KEN)     6       6       1     13
# ...

# %%
alldata=[]
for i in range (2000,2017):
    if(i%4==0):
        temp_data=pd.read_html('https://en.wikipedia.org/wiki/'+str(i)+'_Summer_Olympics_medal_table')
        pdtemp = pd.DataFrame(temp_data[1])
        alldata.append(pdtemp[:20])
        

# html_data = pd.read_html('https://en.wikipedia.org/wiki/2016_Summer_Olympics_medal_table')

# %%
for i in range (len(alldata)):
    print(alldata[i])
# Out:
#    Rank               Nation  Gold  Silver  Bronze  Total
# 0     1  United States (USA)    37      24      32     93
# 1     2         Russia (RUS)    32      28      29     89
# 2     3          China (CHN)    28      16      14     58
# 3     4     Australia (AUS)*    16      25      17     58
# 4     5        Germany (GER)    13      17      26     56
# 5     6         France (FRA)    13      14      11     38
# 6     7          Italy (ITA)    13       8      13     34
# 7     8    Netherlands (NED)    12       9       4     25
# 8     9           Cuba (CUB)    11      11       7     29
# 9    10  Great Britain (GBR)    11      10       7     28
# 10   11        Romania (ROU)    11       6       9     26
# 11   12    South Korea (KOR)     8      10      10     28
# 12   13        Hungary (HUN)     8       6       3     17
# 13   14         Poland (POL)     6       5       3     14
# 14   15          Japan (JPN)     5       8       5     18
# ...

# %%
top20c
# Out:
#    Rank                  NOC  Gold  Silver  Bronze  Total
# 0     1  United States (USA)    46      37      38    121
# 1     2  Great Britain (GBR)    27      23      17     67
# 2     3          China (CHN)    26      18      26     70
# 3     4         Russia (RUS)    19      17      20     56
# 4     5        Germany (GER)    17      10      15     42
# 5     6          Japan (JPN)    12       8      21     41
# 6     7         France (FRA)    10      18      14     42
# 7     8    South Korea (KOR)     9       3       9     21
# 8     9          Italy (ITA)     8      12       8     28
# 9    10      Australia (AUS)     8      11      10     29
# 10   11    Netherlands (NED)     8       7       4     19
# 11   12        Hungary (HUN)     8       3       4     15
# 12   13        Brazil (BRA)*     7       6       6     19
# 13   14          Spain (ESP)     7       4       6     17
# 14   15          Kenya (KEN)     6       6       1     13
# ...

# %%
adultdata = pd.read_csv('adultdata.csv')

# %%
adultdata
# Out:
#                   Age  Workclass       fnlwgt  education        education-num  \
# 39          State-gov      77516    Bachelors         13        Never-married
# 50   Self-emp-not-inc      83311    Bachelors         13   Married-civ-spouse
# 38            Private     215646      HS-grad          9             Divorced
# 53            Private     234721         11th          7   Married-civ-spouse
# 28            Private     338409    Bachelors         13   Married-civ-spouse
# ..                ...        ...          ...        ...                  ...
# 27            Private     257302   Assoc-acdm         12   Married-civ-spouse
# 40            Private     154374      HS-grad          9   Married-civ-spouse
# 58            Private     151910      HS-grad          9              Widowed
# 22            Private     201490      HS-grad          9        Never-married
# 52       Self-emp-inc     287927      HS-grad          9   Married-civ-spouse
#
# ...

# %%
adata = pd.read_table('adult.data', sep = ",")

# %%
atemp = pd.DataFrame(adata)

# %%
atemp[atemp.columns[:-1]]
# Out:
#        Age          Workclass  Fnlwgt    Education  Education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital-status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...
