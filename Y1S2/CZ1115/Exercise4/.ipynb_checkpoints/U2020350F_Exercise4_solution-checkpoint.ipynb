# %% [markdown]
# # Problem 1 : Predicting SalePrice using GrLivArea

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %% [markdown]
# ### a) Plot SalePrice against GrLivArea using any appropriate bivariate plot to note the strong linear relationship.

# %%
houseData = pd.read_csv('train.csv')

sb.jointplot(data = houseData, x = "GrLivArea", y = "SalePrice", height = 10)

# %%
gla = pd.DataFrame(houseData["GrLivArea"])  
sp = pd.DataFrame(houseData["SalePrice"])

# %%
conD = pd.concat([gla, sp], axis = 1).reindex(sp.index)
conD.head()
# Out:
#    GrLivArea  SalePrice
# 0       1710     208500
# 1       1262     181500
# 2       1786     223500
# 3       1717     140000
# 4       2198     250000

# %% [markdown]
# ### b) Print the correlation coefficient between these two variables to get a numerical evidence of the relationship.

# %%
conD.corr()
# Out:
#            GrLivArea  SalePrice
# GrLivArea   1.000000   0.708624
# SalePrice   0.708624   1.000000

# %% [markdown]
# ### c) Import Linear Regression model from Scikit-Learn : from sklearn.linear_model import LinearRegression

# %%
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import train_test_split

# %% [markdown]
# ### d) Partition the dataset houseData into two “random” portions : Train Data (1100 rows) and Test Data (360 rows).

# %%
# # Train Set : 1100 samples
# gla_train = pd.DataFrame(gla[:1100])
# sp_train = pd.DataFrame(sp[:1100])

# # Test Set : 200 samples
# gla_test = pd.DataFrame(gla[-360:])
# sp_test = pd.DataFrame(sp[-360:])


# Split data randomly
gla_train, gla_test, sp_train, sp_test = train_test_split(gla, sp, test_size = 0.246)

print("Train Set :", gla_train.shape, sp_train.shape)
print("Test Set  :", gla_test.shape, sp_test.shape)
# Out:
# Train Set : (1100, 1) (1100, 1)
# Test Set  : (360, 1) (360, 1)

# %% [markdown]
# ### e) Training : Fit a Linear Regression model on the Train Dataset to predict or estimate SalePrice using GrLivArea.

# %%
linreg = LinearRegression()

linreg.fit(gla_train, sp_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### f) Print the coefficients of the Linear Regression model you just fit, and plot the regression line on a scatterplot.

# %%
# Coefficients of the Linear Regression line
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [20020.19897623]
# Coefficients 	: a =  [[106.54585913]]

# %%
# Formula for the Regression line
regline_x = gla_train
regline_y = linreg.intercept_ + linreg.coef_ * gla_train

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(gla_train, sp_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# %% [markdown]
# ### g) Print Explained Variance (R^2) and Mean Squared Error (MSE) on Train Data to check Goodness of Fit of model.

# %%
sp_train_pred = linreg.predict(gla_train)
# Explained Variance (R^2)
print("Explained Variance (R^2) \t:", linreg.score(gla_train, sp_train))

# Mean Squared Error (MSE)
def mean_sq_err(actual, predicted):
    return np.mean(np.square(np.array(actual) - np.array(predicted)))


mse = mean_sq_err(sp_train, sp_train_pred)
print("Mean Squared Error (MSE) \t:", mse)
# Out:
# Explained Variance (R^2) 	: 0.5190835816868018
# Mean Squared Error (MSE) 	: 3057847519.975712

# %% [markdown]
# ### h) Predict SalePrice in case of Test Data using the Linear Regression model and the predictor variable GrLivArea.

# %%
# Predict Total values corresponding to HP Test
sp_test_pred = linreg.predict(gla_test)

# %% [markdown]
# ### i) Plot the predictions on a Scatterplot of GrLivArea and SalePrice in the Test Data to visualize model accuracy.

# %%
# Plot the Predictions
f = plt.figure(figsize=(16, 8))
plt.scatter(gla_test, sp_test, color = "green")
plt.scatter(gla_test, sp_test_pred, color = "red")
plt.show()

# %% [markdown]
# ### j) Print the Mean Squared Error (MSE) on Test Data to check Goodness of Fit of model, compared to the Training.

# %%
# Explained Variance (R^2)
print("Explained Variance (R^2) \t:", linreg.score(gla_test, sp_test))

# Mean Squared Error (MSE)
def mean_sq_err(actual, predicted):
    return np.mean(np.square(np.array(actual) - np.array(predicted)))

mse = mean_sq_err(sp_test, sp_test_pred)
print("Mean Squared Error (MSE) \t:", mse)
# Out:
# Explained Variance (R^2) 	: 0.4483629595789378
# Mean Squared Error (MSE) 	: 3392064320.4291096

# %% [markdown]
# # Problem 2 : Predicting SalePrice using Other Variables

# %% [markdown]
# ## LotArea

# %%
la = pd.DataFrame(houseData["LotArea"])

# %%
sb.jointplot(data = houseData, x = "LotArea", y = "SalePrice", height = 5)

# %%
conD1 = pd.concat([la, sp], axis = 1).reindex(sp.index)

# %%
conD1.corr()
# Out:
#             LotArea  SalePrice
# LotArea    1.000000   0.263843
# SalePrice  0.263843   1.000000

# %%
la_train, la_test, sp_train, sp_test = train_test_split(la, sp, test_size = 0.246)

# %%
linreg.fit(la_train, sp_train)
# Out:
# LinearRegression()

# %%
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [154708.89790492]
# Coefficients 	: a =  [[2.39841407]]

# %%
regline_x = la_train
regline_y = linreg.intercept_ + linreg.coef_ * la_train

f = plt.figure(figsize=(16, 8))
plt.scatter(la_train, sp_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# %%
sp_train_pred = linreg.predict(la_train)
print("Explained Variance (R^2) \t:", linreg.score(la_train, sp_train))
def mean_sq_err(actual, predicted):
    return np.mean(np.square(np.array(actual) - np.array(predicted)))

mse = mean_sq_err(sp_train, sp_train_pred)
print("Mean Squared Error (MSE) \t:", mse)
# Out:
# Explained Variance (R^2) 	: 0.07427653788628719
# Mean Squared Error (MSE) 	: 5823219292.349286

# %%
sp_test_pred = linreg.predict(la_test)

# %%
f = plt.figure(figsize=(16, 8))
plt.scatter(la_test, sp_test, color = "green")
plt.scatter(la_test, sp_test_pred, color = "red")
plt.show()

# %%
print("Explained Variance (R^2) \t:", linreg.score(la_test, sp_test))

def mean_sq_err(actual, predicted):
    return np.mean(np.square(np.array(actual) - np.array(predicted)))

mse = mean_sq_err(sp_test, sp_test_pred)
print("Mean Squared Error (MSE) \t:", mse)
# Out:
# Explained Variance (R^2) 	: 0.046551897019047384
# Mean Squared Error (MSE) 	: 6043750219.466825

# %% [markdown]
# ## TotalBsmtSF

# %%
tbs = pd.DataFrame(houseData["TotalBsmtSF"])

# %%
sb.jointplot(data = houseData, x = "TotalBsmtSF", y = "SalePrice", height = 5)

# %%
conD2 = pd.concat([tbs, sp], axis = 1).reindex(sp.index)

# %%
conD2.corr()
# Out:
#              TotalBsmtSF  SalePrice
# TotalBsmtSF     1.000000   0.613581
# SalePrice       0.613581   1.000000

# %%
tbs_train, tbs_test, sp_train, sp_test = train_test_split(tbs, sp, test_size = 0.246)

# %%
linreg.fit(tbs_train, sp_train)
# Out:
# LinearRegression()

# %%
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [68175.99054325]
# Coefficients 	: a =  [[105.77913799]]

# %%
regline_x = tbs_train
regline_y = linreg.intercept_ + linreg.coef_ * tbs_train

f = plt.figure(figsize=(16, 8))
plt.scatter(tbs_train, sp_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# %%
sp_train_pred = linreg.predict(tbs_train)
print("Explained Variance (R^2) \t:", linreg.score(tbs_train, sp_train))
def mean_sq_err(actual, predicted):
    return np.mean(np.square(np.array(actual) - np.array(predicted)))

mse = mean_sq_err(sp_train, sp_train_pred)
print("Mean Squared Error (MSE) \t:", mse)
# Out:
# Explained Variance (R^2) 	: 0.3643752235421449
# Mean Squared Error (MSE) 	: 3914049579.2558107

# %%
sp_test_pred = linreg.predict(tbs_test)

# %%
f = plt.figure(figsize=(16, 8))
plt.scatter(tbs_test, sp_test, color = "green")
plt.scatter(tbs_test, sp_test_pred, color = "red")
plt.show()

# %%
print("Explained Variance (R^2) \t:", linreg.score(tbs_test, sp_test))

def mean_sq_err(actual, predicted):
    return np.mean(np.square(np.array(actual) - np.array(predicted)))

mse = mean_sq_err(sp_test, sp_test_pred)
print("Mean Squared Error (MSE) \t:", mse)
# Out:
# Explained Variance (R^2) 	: 0.4064097821332139
# Mean Squared Error (MSE) 	: 4013862837.4406805

# %% [markdown]
# ## GarageArea

# %%
ga = pd.DataFrame(houseData["GarageArea"])

# %%
sb.jointplot(data = houseData, x = "GarageArea", y = "SalePrice", height = 5)

# %%
conD3 = pd.concat([ga, sp], axis = 1).reindex(sp.index)

# %%
conD3.corr()
# Out:
#             GarageArea  SalePrice
# GarageArea    1.000000   0.623431
# SalePrice     0.623431   1.000000

# %%
ga_train, ga_test, sp_train, sp_test = train_test_split(ga, sp, test_size = 0.246)

# %%
linreg.fit(ga_train, sp_train)
# Out:
# LinearRegression()

# %%
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [73919.21623882]
# Coefficients 	: a =  [[224.82564593]]

# %%
regline_x = ga_train
regline_y = linreg.intercept_ + linreg.coef_ * ga_train

f = plt.figure(figsize=(16, 8))
plt.scatter(ga_train, sp_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# %%
sp_train_pred = linreg.predict(ga_train)
print("Explained Variance (R^2) \t:", linreg.score(ga_train, sp_train))
def mean_sq_err(actual, predicted):
    return np.mean(np.square(np.array(actual) - np.array(predicted)))

mse = mean_sq_err(sp_train, sp_train_pred)
print("Mean Squared Error (MSE) \t:", mse)
# Out:
# Explained Variance (R^2) 	: 0.3534834104953609
# Mean Squared Error (MSE) 	: 4191792540.177475

# %%
sp_test_pred = linreg.predict(ga_test)

# %%
f = plt.figure(figsize=(16, 8))
plt.scatter(ga_test, sp_test, color = "green")
plt.scatter(ga_test, sp_test_pred, color = "red")
plt.show()

# %%
print("Explained Variance (R^2) \t:", linreg.score(ga_test, sp_test))

def mean_sq_err(actual, predicted):
    return np.mean(np.square(np.array(actual) - np.array(predicted)))

mse = mean_sq_err(sp_test, sp_test_pred)
print("Mean Squared Error (MSE) \t:", mse)
# Out:
# Explained Variance (R^2) 	: 0.5072264602303405
# Mean Squared Error (MSE) 	: 2838544785.300641

# %% [markdown]
# ## GrLivArea
# #### Explained Variance (R^2) 	: 0.4483629595789378
# #### Mean Squared Error (MSE) 	: 3392064320.4291096
#
# ## LotArea
# #### Explained Variance (R^2) 	: 0.046551897019047384
# #### Mean Squared Error (MSE) 	: 6043750219.466825
#
# ## TotalBsmtSF
# #### Explained Variance (R^2) 	: 0.4064097821332139
# #### Mean Squared Error (MSE) 	: 4013862837.4406805
#
# ## GarageArea
# #### Explained Variance (R^2) 	: 0.5072264602303405
# #### Mean Squared Error (MSE) 	: 2838544785.300641

# %% [markdown]
# #### By comparison GarageArea has the highest Explained Variance (R^2) and lowest Mean Squared Error (MSE)
# #### GarageArea is the best model to predict "SalePrice".
