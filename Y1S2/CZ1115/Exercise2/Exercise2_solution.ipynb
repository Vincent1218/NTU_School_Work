# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
traindata = pd.read_csv('train.csv')
traindata.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
print(traindata.dtypes)
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
df = pd.DataFrame(traindata)
df.select_dtypes(include=[np.int64])
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        1          60     8450            7            5       2003
# 1        2          20     9600            6            8       1976
# 2        3          60    11250            7            5       2001
# 3        4          70     9550            7            5       1915
# 4        5          60    14260            8            5       2000
# ...    ...         ...      ...          ...          ...        ...
# 1455  1456          60     7917            6            5       1999
# 1456  1457          20    13175            6            6       1978
# 1457  1458          70     9042            7            9       1941
# 1458  1459          20     9717            5            6       1950
# 1459  1460          20     9937            5            6       1965
#
#       YearRemodAdd  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  WoodDeckSF  \
# ...

# %%
nd = pd.DataFrame(df[["LotArea","BsmtFinSF1","BsmtFinSF2","BsmtUnfSF","TotalBsmtSF","1stFlrSF","2ndFlrSF","LowQualFinSF","GrLivArea","BsmtFullBath","BsmtHalfBath","FullBath","HalfBath","TotRmsAbvGrd","Fireplaces","GarageArea","WoodDeckSF","OpenPorchSF","EnclosedPorch","3SsnPorch","ScreenPorch","PoolArea","MiscVal","SalePrice"]])

# %%
nd
# Out:
#       LotArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# 0        8450         706           0        150          856       856
# 1        9600         978           0        284         1262      1262
# 2       11250         486           0        434          920       920
# 3        9550         216           0        540          756       961
# 4       14260         655           0        490         1145      1145
# 5       14115         732           0         64          796       796
# 6       10084        1369           0        317         1686      1694
# 7       10382         859          32        216         1107      1107
# 8        6120           0           0        952          952      1022
# 9        7420         851           0        140          991      1077
# 10      11200         906           0        134         1040      1040
# 11      11924         998           0        177         1175      1182
# ...

# %%
pd.set_option('display.max_columns', None)
nd.describe()
# Out:
#              LotArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  TotalBsmtSF  \
# count    1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean    10516.828082   443.639726    46.549315   567.240411  1057.429452
# std      9981.264932   456.098091   161.319273   441.866955   438.705324
# min      1300.000000     0.000000     0.000000     0.000000     0.000000
# 25%      7553.500000     0.000000     0.000000   223.000000   795.750000
# 50%      9478.500000   383.500000     0.000000   477.500000   991.500000
# 75%     11601.500000   712.250000     0.000000   808.000000  1298.250000
# max    215245.000000  5644.000000  1474.000000  2336.000000  6110.000000
#
#           1stFlrSF     2ndFlrSF  LowQualFinSF    GrLivArea  BsmtFullBath  \
# count  1460.000000  1460.000000   1460.000000  1460.000000   1460.000000
# mean   1162.626712   346.992466      5.844521  1515.463699      0.425342
# std     386.587738   436.528436     48.623081   525.480383      0.518911
# ...

# %%
salep = nd["SalePrice"]

# %%
salep.describe()
# Out:
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000

# %%
f = plt.figure(figsize=(24, 4))
sb.boxplot(data = salep, orient = "h")
# Out:
# <AxesSubplot:>

# %%
f = plt.figure(figsize=(16, 8))
sb.histplot(data = salep)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
f = plt.figure(figsize=(16, 8))
sb.kdeplot(data = salep)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
f = plt.figure(figsize=(16, 8))
sb.histplot(data = salep, kde = True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
f = plt.figure(figsize=(16, 8))
sb.violinplot(data = salep, orient = "h")
# Out:
# <AxesSubplot:>

# %%
la = numeric_data[["LotArea"]]

# %%
la.describe()
# Out:
#              LotArea
# count    1460.000000
# mean    10516.828082
# std      9981.264932
# min      1300.000000
# 25%      7553.500000
# 50%      9478.500000
# 75%     11601.500000
# max    215245.000000

# %%
f = plt.figure(figsize=(24, 4))
sb.boxplot(data = la, orient = "h")
# Out:
# <AxesSubplot:>

# %%
f = plt.figure(figsize=(16, 8))
sb.histplot(data = la)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
f = plt.figure(figsize=(16, 8))
sb.kdeplot(data = la)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
f = plt.figure(figsize=(16, 8))
sb.histplot(data = la, kde = True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
f = plt.figure(figsize=(16, 8))
sb.violinplot(data = la, orient = "h")
# Out:
# <AxesSubplot:>

# %%
jointDF = pd.concat([salep, la], axis = 1).reindex(la.index)
jointDF
# Out:
#       SalePrice  LotArea
# 0        208500     8450
# 1        181500     9600
# 2        223500    11250
# 3        140000     9550
# 4        250000    14260
# 5        143000    14115
# 6        307000    10084
# 7        200000    10382
# 8        129900     6120
# 9        118000     7420
# 10       129500    11200
# 11       345000    11924
# 12       144000    12968
# 13       279500    10652
# 14       157000    10920
# 15       132000     6120
# 16       149000    11241
# 17        90000    10791
# 18       159000    13695
# 19       139000     7560
# 20       325300    14215
# 21       139400     7449
# 22       230000     9742
# 23       129900     4224
# 24       154000     8246
# 25       256300    14230
# 26       134800     7200
# 27       306000    11478
# 28       207500    16321
# 29        68500     6324
# 30        40000     8500
# 31       149350     8544
# 32       179900    11049
# 33       165500    10552
# 34       277500     7313
# 35       309000    13418
# ...

# %%
sb.jointplot(data = jointDF, x = "SalePrice", y = "LotArea", height = 12)

# %%
jointDF.corr()
# Out:
#            SalePrice   LotArea
# SalePrice   1.000000  0.263843
# LotArea     0.263843  1.000000

# %%
sb.heatmap(jointDF.corr(), vmin = -1, vmax = 1, annot = True, fmt=".3f")
# Out:
# <AxesSubplot:>

# %%
f = plt.figure(figsize=(24, 4))
sb.boxplot(data = nd, orient = "h")
# Out:
# <AxesSubplot:>
